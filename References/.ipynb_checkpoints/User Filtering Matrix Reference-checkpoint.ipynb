# %% [markdown]
# Found this project notebook on Kaggle where I sourced my dataset.  I used his reduce memory function quite often in my project to make manipulating the data easier.  Additionally, I felt like if I could implement a user game matrix into my existing algorithm I could refine the output.  As the output of this recommender is rather linear and focuses primarily on items and users that are similar to each other.
#
# Might implement a version of this at a later date.
#
# Source is https://www.kaggle.com/code/thakursankalp/steam-game-recommendation-engine by user Sankalp Thakur

# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\matth\anaconda3new\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\matth\anaconda3new\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matth\anaconda3new\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matth\anaconda3new\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\matth\anaconda3new\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matth\anaconda3new\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\matth\anaconda3new\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from scipy.sparse import csr_matrix
from mlxtend.frequent_patterns import apriori, association_rules

# Function to reduce the memory usage of a DataFrame.
def reduce_memory(df):
    for col in df.columns:
        if df[col].dtype == 'float64':
            df[col] = df[col].astype('float32')
        if df[col].dtype == 'int64':
            df[col] = df[col].astype('int32')
    return df

# Generator function to load data in chunks.
def data_generator(df, chunksize=10000):
    for i in range(0, df.shape[0], chunksize):
        yield df.iloc[i:i+chunksize]


games = reduce_memory(pd.read_csv('../Data/games.csv'))
users = reduce_memory(pd.read_csv('../Data/users.csv'))
recommendations = reduce_memory(pd.read_csv('../Data/recommendations.csv'))

# %%
from scipy.sparse import coo_matrix

# map each user and item to a unique numeric value
user_ids = recommendations['user_id'].astype('category').cat.codes
item_ids = recommendations['app_id'].astype('category').cat.codes

# Get the unique user and game ids
unique_user_ids = recommendations['user_id'].astype('category').cat.categories
unique_item_ids = recommendations['app_id'].astype('category').cat.categories

# create a sparse matrix
user_game_matrix = coo_matrix((recommendations['hours'], (user_ids, item_ids)))

# Fit the model
model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_knn.fit(user_game_matrix)


# Get top 5 recommendations for first user
distances, indices = model_knn.kneighbors(user_game_matrix.getrow(0), n_neighbors=6)
recommended_users = [unique_user_ids[i] for i in indices.flatten()[1:]]
print(f'Recommended users for the first user are: {recommended_users}')
# Out:
# Recommended users for the first user are: [11422900, 7483536, 9284221, 6590596, 11161013]

# %%
# Content-Based Filtering
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=1, stop_words='english')
tfidf_matrix = tf.fit_transform(games['title'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# Get top 5 recommendations for first game
similar_indices = cosine_similarities[0].argsort()[:-6:-1]
recommended_games = [games['title'].iloc[i] for i in similar_indices]
print(f'Recommended games for the first game are: {recommended_games}')
# Out:
# Recommended games for the first game are: ['Prince of Persia: Warrior Within™', 'Prince of Persia®', 'Prince of Persia: The Two Thrones™', 'Prince of Persia®: The Sands of Time', 'Prince of Persia: The Forgotten Sands™']

# %%
import numpy as np

def get_similar_users(user_id, user_game_matrix, model_knn, n_neighbors=6):
    distances, indices = model_knn.kneighbors(user_game_matrix.getrow(user_id), n_neighbors=n_neighbors)
    similar_users = [unique_user_ids[i] for i in indices.flatten()[1:]]
    return similar_users

# Get the unique game ids
unique_game_ids = recommendations['app_id'].astype('category').cat.categories

def get_similar_games(game_id, tfidf_matrix, n_neighbors=6):
    # Find the positional index of the game_id
    game_index = np.where(unique_game_ids == game_id)[0][0]
    
    cosine_similarities = linear_kernel(tfidf_matrix[game_index], tfidf_matrix).flatten()
    similar_indices = cosine_similarities.argsort()[:-n_neighbors:-1]
    similar_games = [games['title'].iloc[i] for i in similar_indices]
    return similar_games

def recommend_games(user_id):
    similar_users = get_similar_users(user_id, user_game_matrix, model_knn)
    similar_games = []
    for user in similar_users:
        user_games = recommendations[recommendations['user_id'] == user]['app_id'].unique()
        for game_id in user_games:
            similar_games.extend(get_similar_games(game_id, tfidf_matrix))
    return similar_games

# %%
recommend_games(0)
# Out:
# ['Deus Ex: Game of the Year Edition',
#  'Fallout 3: Game of the Year Edition',
#  'BADLAND: Game of the Year Edition',
#  'ConflictCraft 2 - Game of the Year Edition',
#  'Rising Storm Game of the Year Edition',
#  'Super High Ball: Pinball Platformer',
#  'Almost There: The Platformer',
#  'The Ball',
#  '8 Ball 2',
#  'THE E BALL',
#  'Outward Soundtrack',
#  'Outward: The Three Brothers',
#  'Outward - The Soroboreans',
#  'Soundtrack',
#  'Out There Somewhere - Soundtrack',
#  'HeapVR',
#  'FatalZone',
#  'Hunt: Showdown - Double or Nothing',
#  'Horror Bar VR',
#  'Gigant',
#  'Super High Ball: Pinball Platformer',
#  'Almost There: The Platformer',
#  'The Ball',
#  '8 Ball 2',
#  'THE E BALL',
#  'Age of Mythology: Extended Edition',
#  'Anna - Extended Edition',
#  'Transient: Extended Edition',
#  'Age of Mythology EX: Tale of the Dragon',
#  'D.N.Age',
#  'TerraTech - Weapons of War Pack',
#  'TerraTech',
#  'Too Many Weapons',
#  'Kold War Pack',
#  'Steel Division 2 - Back To War Pack',
#  'Borderlands 2: Headhunter 4: Wedding Day Massacre',
#  'Borderlands 2: Headhunter 3: Mercenary Day',
#  'Borderlands 2: Headhunter 1: Bloody Harvest',
#  'Borderlands 2: Headhunter 5: Son of Crawmerax',
#  'Borderlands 2: Headhunter 2: Wattle Gobbler',
#  '沉睡的法则 Things as They Are',
#  'Four Last Things',
#  'My Hidden Things',
#  'Winter Things',
#  'Desert Things',
#  'Super High Ball: Pinball Platformer',
#  'Almost There: The Platformer',
#  'The Ball',
#  '8 Ball 2',
#  'THE E BALL',
#  'OMSI 2 Add-On Citybus i280 Series',
#  'OMSI 2 Add-on Citybus S31X',
#  'OMSI 2 Add-On Citybus O305G',
#  'OMSI 2 Add-On Citybus M301',
#  'OMSI 2 Add-on Citybus i260 Series',
#  'Age of Mythology: Extended Edition',
#  'Anna - Extended Edition',
#  'Transient: Extended Edition',
#  'Age of Mythology EX: Tale of the Dragon',
#  'D.N.Age',
#  "~necromancy~Emily's Escape",
#  'Hands of Necromancy',
#  'Escape First',
#  'Last Escape',
#  'Escape',
#  'TEOCIDA',
#  'FatalZone',
#  'Hunt: Showdown - Double or Nothing',
#  'Pinball FX3 - Williams™ Pinball: Volume 6',
#  'Horror Bar VR',
#  'Heart of the House',
#  'Where is my Heart?',
#  'The House of E.',
#  'My House',
#  'House',
#  'Zorro The Chronicles',
#  'Puzzle Chronicles',
#  'Valkyria Chronicles™',
#  'Toilet Chronicles',
#  'Chronicles of cyberpunk',
#  'Haiku the Robot',
#  'World of Haiku',
#  'The Sound of Fireworks: The Haiku',
#  'Robot Island',
#  'The Girl and the Robot',
#  'Saints Row: The Third - Special Ops Vehicle Pack',
#  'Saints Row 2',
#  'Saints Row',
#  'Saints Row: The Third',
#  'Saints Row®: The Third™ Remastered',
#  'Ballads of Reemus: When the Bed Bites',
#  'Back to Bed',
#  'Love Bites',
#  'Ballads at Midnight',
#  'Bed Survival!',
#  'Super High Ball: Pinball Platformer',
#  'Almost There: The Platformer',
#  'The Ball',
#  '8 Ball 2',
#  'THE E BALL',
#  'Spooky Halloween in the Voxel World',
#  'Travel Mosaics 10: Spooky Halloween',
#  'Voxel Tycoon',
#  'Voxel Race',
#  'The Last World',
#  'Toaster Jam',
#  'Toaster Defense',
#  'JAM GODS',
#  'GUN JAM',
#  'Pirate Jam',
#  'Trump Simulator VR',
#  'Survival Simulator VR',
#  'Cooking Simulator VR',
#  'HUNTING SIMULATOR VR',
#  'Thief Simulator VR',
#  'Syrian Warfare Original Soundtrack',
#  'Syrian Warfare',
#  'Syrian Warfare: Battlefields',
#  'We Were Here: Original Soundtrack',
#  'Never Alone: Original Soundtrack',
#  'SnowNight',
#  'FatalZone',
#  'Hunt: Showdown - Double or Nothing',
#  'Horror Bar VR',
#  'Gigant',
#  "Beat Saber: Skrillex – 'Bangarang (feat. Sirah)'",
#  "Beat Saber: Skrillex – 'Rock ‘n’ Roll (Will Take You to the Mountain)'",
#  'Beat Saber',
#  'Beat Saber - Marshmello - Alone',
#  'Beat Me If You Can',
#  'The Soul Stone War 2',
#  'The Soul Stone War',
#  'STONE',
#  'Soul for two',
#  'After The War',
#  'Age of Mythology: Extended Edition',
#  'Anna - Extended Edition',
#  'Transient: Extended Edition',
#  'Age of Mythology EX: Tale of the Dragon',
#  'D.N.Age',
#  'Dujanah',
#  'FatalZone',
#  'Pinball FX3 - Williams™ Pinball: Volume 6',
#  'Horror Bar VR',
#  'Gigant',
#  'Batman: Arkham Origins - Black Mask Challenge Pack',
#  'Batman™: Arkham Origins',
#  'Batman: Arkham Origins - Initiation',
#  'Batman™: Arkham Origins - Season Pass',
#  'Batman™: Arkham Origins Blackgate - Deluxe Edition',
#  '2089 - Space Divided',
#  'CuberPunk 2089',
#  'BACK OF SPACE',
#  'ALONE IN SPACE',
#  'Out of Space',
#  'Pathologic Classic HD',
#  'Pathologic 2',
#  'Pathologic 2: Soundtrack',
#  'Pathologic 2: Artbook',
#  'Pathologic 2: Marble Nest',
#  'Star Trek: Starfleet Command Gold Edition',
#  'Star Trek™: Starfleet Academy',
#  'Star Trek Online',
#  'Star Trek: Infinite',
#  'Star Trek Timelines',
#  'Super Psycho Baseball',
#  'PSYCHO',
#  'Psycho',
#  'Super',
#  'Psycho Train',
#  'Super High Ball: Pinball Platformer',
#  'Almost There: The Platformer',
#  'The Ball',
#  '8 Ball 2',
#  'THE E BALL']
